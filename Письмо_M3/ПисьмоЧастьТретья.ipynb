# %% [markdown]
# # Письмо третье
#
# https://mail.yandex.ru/?uid=191623657#message/187743809466036377
#
# Доброго дня! <br/>
# Продолжается работа по подготовке комплектов ФОСов. <br/>
# Просим в срок до 9.11.2024 подготовить ФОСы по дисциплинам: <br/>
#
# | Дисциплина | Направление | Профиль |
# |---|---|---|
# | Разработка мобильных приложений (ПМ.01; МДК.01.03) | 09.02.07. | Программист |
# | Системное программирование (ПМ.01; МДК.01.04) | 09.02.07. | Программист |

# %% [markdown]
# Количество тестовых заданий зависит от количества компетенций, сформированных в рамках конкретной дисциплины:
#
# |Количество часов|Количество тестовых заданий|Количество тестовых заданий|Количество тестовых заданий|Количество тестовых заданий|
# |---|---|---|---|---|
# |Количество часов|Закрытого типа|Напоследовательность <br/> и установление соответствия|Открытого типа|Итого|
# |на одну ок <br/> компетенцию <br/> разрабатывается <br/> не менее|10|5|5|20|
# |на одну пк <br/> компетенцию <br/> разрабатывается <br/> не менее|10|10|20|40|

# %% [markdown]
# Таким образом, если у Вас в дисциплине 1 ОК и 1 ПК, нужно готовить 20 + 40 = 80 вопросов, из которых 20 будут закрытого типа, 15 на последовательсть и установление соответствия, 25 открытого типа. <br/>
# В каждом вопросе должно быть не менее 4 вариантов ответа. Намного больше тоже лучше не делать, чтобы не увеличивать искусственно объем работы. <br/>
# Прикрепляю шаблон для ОМ (обычные дисциплины), шаблон для ОМ в рамках ПМ (дисциплины, включенные в профессиональные модули). <br/>
# В случае, если у Вас несколько идентичных дисциплин - настоятельно рекомендуем проявить сознательность и оптимизировать свою работу.<br/>
# С уважением, Чантурия Георгий Темурович, Методист, Кафедра цифровой экономики
